# %%
##Defining graph in form of a dictionary
graph = {1 : [8,14],
         3 : [51,6,9],
         6 : [3,8,51,57],
         8 : [1,6,9,42],
         9 : [3,8],
         14 : [1,97],
         42 : [],
         51 : [3,6],
         57 : [],
         97 : []}

# %%
#Function 'bfs' 
##keep track on all visited noeds and queue for the next node to be checked.
def bfs(g,start):
    visited = []
    queue = [start]
##Tracking(looping) till all nodes are not traversed.
    while queue:
        node = queue.pop(0)
        if node not in visited:
            visited.append(node)
            neighbours = graph[node]
##Add neigbour nodes to the queue            
            for neighbour in neighbours:
                queue.append(neighbour)
    return visited

# %%
##FunctionCall(bfs(dictionaryname,node))
bfs(g,1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-d75e5d0138c0> in <module>
#       1 ##FunctionCall(bfs(dictionaryname,node))
# ----> 2 bfs(g,1)
#
# NameError: name 'g' is not defined
